# %%
import pandas as pd

# %%
data = [('n_pregnant', 0, 0.0),
 ('gtt', 5, 0.00651890482398957),
 ('blood_pressure', 35, 0.04563233376792699),
 ('triceps_skin_fold_thickness', 227, 0.29595827900912647),
 ('insulin', 373, 0.4863102998696219),
 ('bmi', 11, 0.014341590612777053),
 ('dpf', 0, 0.0),
 ('age', 0, 0.0),
 ('class', 0, 0.0)]
# create dataframe 
df = pd.DataFrame(data, columns = ['Feature', 'Missing', 'Missing %'])
# sort and plot
df.sort_values(by='Missing %', ascending=False, inplace=True)
df.plot.bar(x='Feature', y='Missing %', rot=90, figsize=(10,5))
# Out:
# <Axes: xlabel='Feature'>
